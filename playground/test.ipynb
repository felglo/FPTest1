# %%
import fptest1 as fp

# %%
print(fp.hello())
print(fp.pauli_x())
print(fp.pauli_y())
print(fp.pauli_z())

assert (fp.pauli_x() @ fp.pauli_y() == 1j * fp.pauli_z()).all()
# Out:
# Hello from fptest1!
# [[0 1]
#  [1 0]]
# [[ 0.+0.j -0.-1.j]
#  [ 0.+1.j  0.+0.j]]
# [[ 1  0]
#  [ 0 -1]]
